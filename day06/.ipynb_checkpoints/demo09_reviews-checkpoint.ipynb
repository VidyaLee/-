# %%
#电影评论情感分析
#corpus语料库
import nltk.corpus as nc
import nltk.classify as cf
import nltk.classify.util as cu
import numpy as np

import nltk
nltk.download('movie_reviews')

pdata=[]
fileids=nc.movie_reviews.fileids('pos')
for fileid in fileids:
    sample={}
    words=nc.movie_reviews.words(fileid)
    for word in words:
        sample[word]=True
    pdata.append((sample,'POSITIVE'))
pdata=np.array(pdata)
print(pdata)

ndata=[]
fileids=nc.movie_reviews.fileids('neg')
for fileid in fileids:
    sample={}
    words=nc.movie_reviews.words(fileid)
    for word in words:
        sample[word]=True
    ndata.append((sample,'NEGATIVE'))
#整理数据集，80%训练  20%测试
pnumb,nnumb =int(len(pdata)*0.8),int(len(ndata)*0.2)
train_data=pdata[:pnumb]+ndata[:nnumb]

cf.NaiveBayesClassifier.train(train_data)
cu.accuracy(model,test_data)
print(ac)
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\88\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# ...
