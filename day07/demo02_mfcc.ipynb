# %%
#mfcc梅尔频率倒谱系数
#提取语音内容
import scipy.io.wavfile as wf
#Scipy可以处理最优化、线性代数、积分、插值、拟合、特殊函数、快速傅里叶变换、信号处理、图像处理、常微分方程求解器等
import python_speech_features as sf
import matplotlib.pyplot as mp

#sig位移点
sample_rate,sigs=wf.read('../ml_data/freq.wav')    #wavfile音频文件  wave波形
print(sample_rate,sigs.shape)
mfcc=sf.mfcc(sigs,sample_rate)
mp.imshow(mfcc.T,cmap='gist_rainbow')
mp.tight_layout()
mp.show()
# Out:
# 8000 (3251,)

# %%
#mfcc梅尔频率倒谱系数
#提取语音内容
import scipy.io.wavfile as wf
#Scipy可以处理最优化、线性代数、积分、插值、拟合、特殊函数、快速傅里叶变换、信号处理、图像处理、常微分方程求解器等
import python_speech_features as sf
import matplotlib.pyplot as mp

#sig位移点
sample_rate,sigs=wf.read('../ml_data/speeches/training/apple/apple01.wav')    #wavfile音频文件  wave波形
print(sample_rate,sigs.shape)
mfcc=sf.mfcc(sigs,sample_rate)
mp.imshow(mfcc.T,cmap='gist_rainbow')
mp.tight_layout()#tight_layout()  自动调整子图参数，使之填充整个图像区域。

mp.show()
# Out:
# 8000 (2694,)

# %%
#mfcc梅尔频率倒谱系数
#提取语音内容
import scipy.io.wavfile as wf
#Scipy可以处理最优化、线性代数、积分、插值、拟合、特殊函数、快速傅里叶变换、信号处理、图像处理、常微分方程求解器等
import python_speech_features as sf
import matplotlib.pyplot as mp

#sig位移点
sample_rate,sigs=wf.read('../ml_data/speeches/training/banana/banana01.wav')    #wavfile音频文件  wave波形
print(sample_rate,sigs.shape)
mfcc=sf.mfcc(sigs,sample_rate)
mp.imshow(mfcc.T,cmap='gist_rainbow')
mp.tight_layout()#tight_layout()  自动调整子图参数，使之填充整个图像区域。

mp.show()
# Out:
# 8000 (3437,)
