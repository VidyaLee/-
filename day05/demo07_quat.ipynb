# %%
#图像量化
import numpy as np
import scipy.misc as sm
import sklearn.cluster as sc
import matplotlib.pyplot as mp

original=sm.imread('../ml_data/lily.jpg',True)
print(original.shape)
mp.subplot(121)
mp.imshow(original,cmap='gray')
mp.axis('off')
mp.tight_layout() #布局
#基于KMean算法实现图像量化
model=sc.KMeans(n_clusters=2)
#一行一样本，一列一特征
x=original.reshape(-1,1)
model.fit(x)
y=model.labels_
centers=model.cluster_centers_
print(y)
print(centers)       

newimage=centers[y].reshape(original.shape )
mp.subplot(122)
mp.imshow(original,cmap='gray')
mp.axis('off')
mp.tight_layout() #布局

mp.show()
# Out:
# C:\Users\88\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   import sys
# (512, 512)
# [1 1 1 ... 1 1 1]
# [[195.05585 ]
#  [ 58.889057]]
